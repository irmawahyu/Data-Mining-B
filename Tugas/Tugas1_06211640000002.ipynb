# %% [markdown]
# # Irma Wahyu Rosanti (06211640000002)
# ### Restaurant & Consumer Data
# ##### Sumber : UCI Machine Learning Repository

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Data

# %%
Biodata = pd.read_csv (r'e:\Documents\userprofile.csv', delimiter=';') 
Lokasi = pd.read_csv(r'e:\Documents\places.csv', delimiter=';')
Rating = pd.read_csv(r'e:\Documents\rating_final.csv', delimiter=';')
Pembayaran = pd.read_csv(r'e:\Documents\userpayment.csv', delimiter=';')

# %%
Biodata
# Out:
#     userID  transport marital_status  birth_year   religion       activity  \
# 0    U1001    on foot         single        1989       none        student
# 1    U1002     public         single        1990   Catholic        student
# 2    U1003     public         single        1989   Catholic        student
# 3    U1004     public         single        1940       none   professional
# 4    U1005     public         single        1992   Catholic        student
# 5    U1006  car owner         single        1989       none        student
# 6    U1007     public         single        1989   Catholic        student
# 7    U1008     public         single        1989   Catholic        student
# 8    U1009    on foot         single        1991   Catholic        student
# 9    U1010  car owner        married        1987       none        student
# 10   U1011     public         single        1989   Catholic        student
# ...

# %%
#Menghapus Kolom
Biodata = Biodata.drop(['transport', 'marital_status','weight','height'], axis=1)
Biodata
# Out:
#     userID  birth_year   religion       activity  budget
# 0    U1001        1989       none        student  medium
# 1    U1002        1990   Catholic        student     low
# 2    U1003        1989   Catholic        student     low
# 3    U1004        1940       none   professional  medium
# 4    U1005        1992   Catholic        student  medium
# 5    U1006        1989       none        student  medium
# 6    U1007        1989   Catholic        student     low
# 7    U1008        1989   Catholic        student     low
# 8    U1009        1991   Catholic        student  medium
# 9    U1010        1987       none        student  medium
# 10   U1011        1989   Catholic        student  medium
# 11   U1012        1988   Catholic        student  medium
# 12   U1013        1982       none   professional  medium
# 13   U1014        1990   Catholic        student  medium
# 14   U1015        1989   Catholic        student  medium
# ...

# %%
Lokasi
# Out:
#      placeID             city            state country            alcohol  \
# 0     134999       Cuernavaca          Morelos  Mexico  No_Alcohol_Served
# 1     132825           s.l.p.           s.l.p.  mexico  No_Alcohol_Served
# 2     135106  San Luis Potosi  San Luis Potosi  Mexico          Wine-Beer
# 3     132667        victoria        tamaulipas       ?  No_Alcohol_Served
# 4     132613         victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 5     135040  San Luis Potosi              SLP  Mexico          Wine-Beer
# 6     132732      Cd Victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 7     132875                ?                ?       ?          Wine-Beer
# 8     132609         victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 9     135082  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 10    135070  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 11    135069  San Luis Potosi              SLP  Mexico          Wine-Beer
# ...

# %%
# Menghapus Kolom
Lokasi = Lokasi.drop(['country','alcohol','smoking_area','other_services'], axis=1)
Lokasi
# Out:
#      placeID             city            state   price
# 0     134999       Cuernavaca          Morelos  medium
# 1     132825           s.l.p.           s.l.p.     low
# 2     135106  San Luis Potosi  San Luis Potosi  medium
# 3     132667        victoria        tamaulipas     low
# 4     132613         victoria       Tamaulipas  medium
# 5     135040  San Luis Potosi              SLP    high
# 6     132732      Cd Victoria       Tamaulipas     low
# 7     132875                ?                ?    high
# 8     132609         victoria       Tamaulipas     low
# 9     135082  San Luis Potosi              SLP  medium
# 10    135070  San Luis Potosi              SLP  medium
# 11    135069  San Luis Potosi              SLP     low
# 12    135065  San Luis Potosi              SLP    high
# 13    135076  San Luis Potosi              SLP    high
# 14    135086  San Luis Potosi              SLP  medium
# 15    132870  San Luis Potosi  San Luis Potosi     low
# ...

# %%
Pembayaran
# Out:
#     userID             Upayment
# 0    U1001                 cash
# 1    U1002                 cash
# 2    U1003                 cash
# 3    U1004                 cash
# 4    U1004     bank_debit_cards
# 5    U1005                 cash
# 6    U1006                 cash
# 7    U1007                 cash
# 8    U1008                 cash
# 9    U1009                 cash
# 10   U1010                 cash
# 11   U1011                 cash
# 12   U1012                 cash
# 13   U1012     bank_debit_cards
# 14   U1013  MasterCard-Eurocard
# 15   U1013                 cash
# 16   U1014                 cash
# 17   U1015                 cash
# 18   U1016                 cash
# 19   U1017                 cash
# 20   U1017                 VISA
# 21   U1018                 cash
# 22   U1019                 cash
# 23   U1020                 cash
# 24   U1020     bank_debit_cards
# 25   U1021                 cash
# 26   U1022                 cash
# 27   U1023                 cash
# ...

# %%
Rating
# Out:
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 2     U1077   132825       2            2               2
# 3     U1077   135060       1            2               2
# 4     U1068   135104       1            1               2
# 5     U1068   132740       0            0               0
# 6     U1068   132663       1            1               1
# 7     U1068   132732       0            0               0
# 8     U1068   132630       1            1               1
# 9     U1067   132584       2            2               2
# 10    U1067   132733       1            1               1
# 11    U1067   132732       1            2               2
# 12    U1067   132630       1            0               1
# 13    U1067   135104       0            0               0
# 14    U1067   132560       1            0               0
# ...

# %%
# unsert new colomn
Rating['rating_total'] =(Rating['rating'] + Rating['food_rating'] + Rating['service_rating'])
Rating
# Out:
#      userID  placeID  rating  food_rating  service_rating  rating_total
# 0     U1077   135085       2            2               2             6
# 1     U1077   135038       2            2               1             5
# 2     U1077   132825       2            2               2             6
# 3     U1077   135060       1            2               2             5
# 4     U1068   135104       1            1               2             4
# 5     U1068   132740       0            0               0             0
# 6     U1068   132663       1            1               1             3
# 7     U1068   132732       0            0               0             0
# 8     U1068   132630       1            1               1             3
# 9     U1067   132584       2            2               2             6
# 10    U1067   132733       1            1               1             3
# 11    U1067   132732       1            2               2             5
# ...

# %%
# menggabungkan 2 tabel
data = pd.merge(Lokasi,Rating, on="placeID")
data
# Out:
#       placeID             city            state   price userID  rating  \
# 0      134999       Cuernavaca          Morelos  medium  U1093       2
# 1      134999       Cuernavaca          Morelos  medium  U1066       1
# 2      134999       Cuernavaca          Morelos  medium  U1040       1
# 3      134999       Cuernavaca          Morelos  medium  U1110       2
# 4      134999       Cuernavaca          Morelos  medium  U1121       2
# 5      132825           s.l.p.           s.l.p.     low  U1077       2
# 6      132825           s.l.p.           s.l.p.     low  U1055       2
# 7      132825           s.l.p.           s.l.p.     low  U1053       1
# 8      132825           s.l.p.           s.l.p.     low  U1081       1
# 9      132825           s.l.p.           s.l.p.     low  U1001       2
# 10     132825           s.l.p.           s.l.p.     low  U1056       2
# 11     132825           s.l.p.           s.l.p.     low  U1134       1
# ...

# %%
# menggabungkan 2 tabel
data1 = pd.merge(Biodata, data, on="userID")
data1
# Out:
#      userID  birth_year  religion activity  budget  placeID             city  \
# 0     U1001        1989      none  student  medium   132825           s.l.p.
# 1     U1001        1989      none  student  medium   135040  San Luis Potosi
# 2     U1001        1989      none  student  medium   135033  San Luis Potosi
# 3     U1001        1989      none  student  medium   135045  San Luis Potosi
# 4     U1001        1989      none  student  medium   135025  San Luis Potosi
# 5     U1001        1989      none  student  medium   135051  San Luis Potosi
# 6     U1001        1989      none  student  medium   132830                ?
# 7     U1001        1989      none  student  medium   135039  San Luis Potosi
# 8     U1001        1989      none  student  medium   135085  San Luis Potosi
# 9     U1002        1990  Catholic  student     low   132825           s.l.p.
# 10    U1002        1990  Catholic  student     low   135106  San Luis Potosi
# ...

# %%
# menggabungkan tabel
data2 = pd.merge(data1, Pembayaran, on='userID')
data2
# Out:
#      userID  birth_year  religion activity  budget  placeID             city  \
# 0     U1001        1989      none  student  medium   132825           s.l.p.
# 1     U1001        1989      none  student  medium   135040  San Luis Potosi
# 2     U1001        1989      none  student  medium   135033  San Luis Potosi
# 3     U1001        1989      none  student  medium   135045  San Luis Potosi
# 4     U1001        1989      none  student  medium   135025  San Luis Potosi
# 5     U1001        1989      none  student  medium   135051  San Luis Potosi
# 6     U1001        1989      none  student  medium   132830                ?
# 7     U1001        1989      none  student  medium   135039  San Luis Potosi
# 8     U1001        1989      none  student  medium   135085  San Luis Potosi
# 9     U1002        1990  Catholic  student     low   132825           s.l.p.
# 10    U1002        1990  Catholic  student     low   135106  San Luis Potosi
# ...

# %%
# mengurutkan kolom
data2 = data2[['userID','birth_year','religion','activity','budget','placeID','city','state','Upayment','price','rating','food_rating','service_rating','rating_total']]
data2
# Out:
#      userID  birth_year  religion activity  budget  placeID             city  \
# 0     U1001        1989      none  student  medium   132825           s.l.p.
# 1     U1001        1989      none  student  medium   135040  San Luis Potosi
# 2     U1001        1989      none  student  medium   135033  San Luis Potosi
# 3     U1001        1989      none  student  medium   135045  San Luis Potosi
# 4     U1001        1989      none  student  medium   135025  San Luis Potosi
# 5     U1001        1989      none  student  medium   135051  San Luis Potosi
# 6     U1001        1989      none  student  medium   132830                ?
# 7     U1001        1989      none  student  medium   135039  San Luis Potosi
# 8     U1001        1989      none  student  medium   135085  San Luis Potosi
# 9     U1002        1990  Catholic  student     low   132825           s.l.p.
# 10    U1002        1990  Catholic  student     low   135106  San Luis Potosi
# ...

# %%
# menghapus baris
data2 = data.drop([6,13,16,27,28])
data2
# Out:
#       placeID             city            state   price userID  rating  \
# 0      134999       Cuernavaca          Morelos  medium  U1093       2
# 1      134999       Cuernavaca          Morelos  medium  U1066       1
# 2      134999       Cuernavaca          Morelos  medium  U1040       1
# 3      134999       Cuernavaca          Morelos  medium  U1110       2
# 4      134999       Cuernavaca          Morelos  medium  U1121       2
# 5      132825           s.l.p.           s.l.p.     low  U1077       2
# 7      132825           s.l.p.           s.l.p.     low  U1053       1
# 8      132825           s.l.p.           s.l.p.     low  U1081       1
# 9      132825           s.l.p.           s.l.p.     low  U1001       2
# 10     132825           s.l.p.           s.l.p.     low  U1056       2
# 11     132825           s.l.p.           s.l.p.     low  U1134       1
# 12     132825           s.l.p.           s.l.p.     low  U1116       2
# ...

# %%
hasil = pd.merge(data1, Pembayaran, how='inner', on='userID')
hasil
# Out:
#      userID  birth_year  religion activity  budget  placeID             city  \
# 0     U1001        1989      none  student  medium   132825           s.l.p.
# 1     U1001        1989      none  student  medium   135040  San Luis Potosi
# 2     U1001        1989      none  student  medium   135033  San Luis Potosi
# 3     U1001        1989      none  student  medium   135045  San Luis Potosi
# 4     U1001        1989      none  student  medium   135025  San Luis Potosi
# 5     U1001        1989      none  student  medium   135051  San Luis Potosi
# 6     U1001        1989      none  student  medium   132830                ?
# 7     U1001        1989      none  student  medium   135039  San Luis Potosi
# 8     U1001        1989      none  student  medium   135085  San Luis Potosi
# 9     U1002        1990  Catholic  student     low   132825           s.l.p.
# 10    U1002        1990  Catholic  student     low   135106  San Luis Potosi
# ...

# %% [markdown]
# ### Concatenating

# %%
R1 = pd.read_csv (r'e:\Documents\rating_1.csv', delimiter=';')  
R2 = pd.read_csv (r'e:\Documents\rating_2.csv', delimiter=';') 
R3 = pd.read_csv (r'e:\Documents\rating_3.csv', delimiter=';')

# %%
R1
# Out:
#    userID  placeID  rating  food_rating  service_rating
# 0   U1077   135085       2            2               2
# 1   U1077   135038       2            2               1
# 2   U1077   132825       2            2               2
# 3   U1077   135060       1            2               2
# 4   U1068   135104       1            1               2
# 5   U1068   132740       0            0               0
# 6   U1068   132663       1            1               1
# 7   U1068   132732       0            0               0
# 8   U1068   132630       1            1               1
# 9   U1067   132584       2            2               2
# 10  U1067   132733       1            1               1
# 11  U1067   132732       1            2               2
# 12  U1067   132630       1            0               1
# 13  U1067   135104       0            0               0
# 14  U1067   132560       1            0               0
# 15  U1103   132584       1            2               1
# ...

# %%
R2
# Out:
#    userID  placeID  rating  food_rating  service_rating
# 0   U1103   132667       1            2               2
# 1   U1103   135104       1            2               0
# 2   U1103   132663       1            0               2
# 3   U1103   132733       2            2               2
# 4   U1107   132660       2            2               1
# 5   U1107   132584       2            2               2
# 6   U1107   132733       2            2               2
# 7   U1044   135088       2            2               2
# 8   U1044   132583       1            2               1
# 9   U1070   132608       2            2               1
# 10  U1070   132609       1            1               1
# 11  U1070   132613       1            1               0
# 12  U1031   132663       0            0               0
# 13  U1031   132665       0            0               0
# 14  U1031   132668       0            0               0
# 15  U1082   132630       1            1               1
# ...

# %%
R3
# Out:
#    userID  placeID  rating  food_rating  service_rating
# 0   U1082   132608       0            0               0
# 1   U1082   132609       0            0               0
# 2   U1082   132663       0            0               0
# 3   U1082   132560       0            0               0
# 4   U1060   132564       2            2               2
# 5   U1060   132717       2            2               2
# 6   U1060   132733       2            1               2
# 7   U1060   132740       1            2               1
# 8   U1015   135071       0            0               0
# 9   U1123   132733       1            2               1
# 10  U1123   132608       1            2               1

# %%
frames = [R1, R2, R3]
hasil = pd.concat(frames)
hasil
# Out:
#    userID  placeID  rating  food_rating  service_rating
# 0   U1077   135085       2            2               2
# 1   U1077   135038       2            2               1
# 2   U1077   132825       2            2               2
# 3   U1077   135060       1            2               2
# 4   U1068   135104       1            1               2
# 5   U1068   132740       0            0               0
# 6   U1068   132663       1            1               1
# 7   U1068   132732       0            0               0
# 8   U1068   132630       1            1               1
# 9   U1067   132584       2            2               2
# 10  U1067   132733       1            1               1
# 11  U1067   132732       1            2               2
# 12  U1067   132630       1            0               1
# 13  U1067   135104       0            0               0
# 14  U1067   132560       1            0               0
# 15  U1103   132584       1            2               1
# ...

# %%
hasil = pd.concat(frames, keys=['X', 'Y', 'Z'])
hasil
# Out:
#      userID  placeID  rating  food_rating  service_rating
# X 0   U1077   135085       2            2               2
#   1   U1077   135038       2            2               1
#   2   U1077   132825       2            2               2
#   3   U1077   135060       1            2               2
#   4   U1068   135104       1            1               2
#   5   U1068   132740       0            0               0
#   6   U1068   132663       1            1               1
#   7   U1068   132732       0            0               0
#   8   U1068   132630       1            1               1
#   9   U1067   132584       2            2               2
#   10  U1067   132733       1            1               1
#   11  U1067   132732       1            2               2
#   12  U1067   132630       1            0               1
#   13  U1067   135104       0            0               0
#   14  U1067   132560       1            0               0
# ...
